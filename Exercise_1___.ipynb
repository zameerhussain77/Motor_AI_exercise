# %%
#import libs
import rasterio
from rasterio.warp import reproject, Resampling
from rasterio.mask import mask
import numpy as np
import os
import zipfile
import geopandas as gpd
# Out:
# /tmp/ipykernel_11201/3327879154.py:7: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
# Paths to your data
road_shapefile = 'roads_filtered.shp'
satellite_image_tif = 'satellite_imagery_testt.tif'
output_dir = 'Tileee_final'

# Create output directory if it does not exist
os.makedirs(output_dir, exist_ok=True)

# %%
def process_tiles():
    if not os.path.isfile(road_shapefile):
        raise FileNotFoundError(f"Shapefile {road_shapefile} does not exist.")

    if not os.path.isfile(satellite_image_tif):
        raise FileNotFoundError(f"TIFF file {satellite_image_tif} does not exist.")
    
    # Load the shapefile
    roads = gpd.read_file(road_shapefile)
    roads['oneway'] = roads['oneway'].astype(str).str.lower()
    filtered_roads = roads[(roads['maxspeed'] >= 50) & (roads['oneway'] == 'f')]
    buffered_roads = filtered_roads.copy()
    buffered_roads['geometry'] = buffered_roads['geometry'].buffer(20)

    # Open the satellite image and apply mask
    with rasterio.open(satellite_image_tif) as src:
        img_crs = src.crs
        img_transform = src.transform
        img_data = src.read()
        img_meta = src.meta.copy()
        
        buffered_roads_geom = buffered_roads.geometry
        out_image, out_transform = mask(src, buffered_roads_geom, crop=True)
        
    # Reproject the image
    dst_crs = 'EPSG:25833'
    reprojected_data = np.empty_like(out_image)
    for i in range(out_image.shape[0]):
        reproject(
            source=out_image[i],
            destination=reprojected_data[i],
            src_transform=out_transform,
            src_crs=src.crs,
            dst_transform=img_transform,
            dst_crs=dst_crs,
            resampling=Resampling.nearest
        )

    out_meta = img_meta.copy()
    out_meta.update({
        'crs': dst_crs,
        'transform': img_transform
    })

    # Define tile size and calculate number of tiles
    tile_size = 512
    n_bands, height, width = reprojected_data.shape

    # Calculate number of tiles needed to cover the full extent
    num_tiles_x = int(np.ceil(width / tile_size))
    num_tiles_y = int(np.ceil(height / tile_size))

    for i in range(num_tiles_y):
        for j in range(num_tiles_x):
            # Define tile bounds
            window = rasterio.windows.Window(
                col_off=j * tile_size,
                row_off=i * tile_size,
                width=min(tile_size, width - j * tile_size),
                height=min(tile_size, height - i * tile_size)
            )
            tile_data = reprojected_data[:, window.row_off:window.row_off + window.height, window.col_off:window.col_off + window.width]
            
            tile_meta = out_meta.copy()
            tile_meta.update({
                'height': tile_data.shape[1],
                'width': tile_data.shape[2],
                'transform': rasterio.windows.transform(window, img_transform)
            })

            tile_filename = os.path.join(output_dir, f'tile_{i * tile_size}_{j * tile_size}.tif')
            with rasterio.open(tile_filename, 'w', **tile_meta) as dest:
                dest.write(tile_data)
            
            print(f'Saved {tile_filename}')

    print('Tiling complete!')

# %%
def zip_tiles(output_dir):
    zip_file_path = os.path.join(output_dir, 'tiles.zip')
    with zipfile.ZipFile(zip_file_path, 'w') as zipf:
        for root, _, files in os.walk(output_dir):
            for file in files:
                if file.endswith('.tif'):
                    file_path = os.path.join(root, file)
                    zipf.write(file_path, os.path.relpath(file_path, output_dir))
    print(f"All tiles have been saved and zipped into {zip_file_path}")

# Process and zip tiles
process_tiles()
zip_tiles(output_dir)
# Out:
# Saved Tileee_final/tile_0_0.tif
# Saved Tileee_final/tile_0_512.tif
# Saved Tileee_final/tile_0_1024.tif
# Saved Tileee_final/tile_0_1536.tif
# Saved Tileee_final/tile_0_2048.tif
# Saved Tileee_final/tile_0_2560.tif
# Saved Tileee_final/tile_0_3072.tif
# Saved Tileee_final/tile_0_3584.tif
# Saved Tileee_final/tile_0_4096.tif
# Saved Tileee_final/tile_0_4608.tif
# Saved Tileee_final/tile_0_5120.tif
# Saved Tileee_final/tile_0_5632.tif
# Saved Tileee_final/tile_0_6144.tif
# Saved Tileee_final/tile_0_6656.tif
# Saved Tileee_final/tile_0_7168.tif
# Saved Tileee_final/tile_0_7680.tif
# Saved Tileee_final/tile_0_8192.tif
# Saved Tileee_final/tile_0_8704.tif
# Saved Tileee_final/tile_0_9216.tif
# Saved Tileee_final/tile_0_9728.tif
# Saved Tileee_final/tile_512_0.tif
# Saved Tileee_final/tile_512_512.tif
# Saved Tileee_final/tile_512_1024.tif
# Saved Tileee_final/tile_512_1536.tif
# Saved Tileee_final/tile_512_2048.tif
# Saved Tileee_final/tile_512_2560.tif
# Saved Tileee_final/tile_512_3072.tif
# Saved Tileee_final/tile_512_3584.tif
# Saved Tileee_final/tile_512_4096.tif
# Saved Tileee_final/tile_512_4608.tif
# Saved Tileee_final/tile_512_5120.tif
# Saved Tileee_final/tile_512_5632.tif
# Saved Tileee_final/tile_512_6144.tif
# Saved Tileee_final/tile_512_6656.tif
# Saved Tileee_final/tile_512_7168.tif
# Saved Tileee_final/tile_512_7680.tif
# Saved Tileee_final/tile_512_8192.tif
# Saved Tileee_final/tile_512_8704.tif
# Saved Tileee_final/tile_512_9216.tif
# Saved Tileee_final/tile_512_9728.tif
# Saved Tileee_final/tile_1024_0.tif
# Saved Tileee_final/tile_1024_512.tif
# Saved Tileee_final/tile_1024_1024.tif
# Saved Tileee_final/tile_1024_1536.tif
# Saved Tileee_final/tile_1024_2048.tif
# Saved Tileee_final/tile_1024_2560.tif
# Saved Tileee_final/tile_1024_3072.tif
# Saved Tileee_final/tile_1024_3584.tif
# Saved Tileee_final/tile_1024_4096.tif
# Saved Tileee_final/tile_1024_4608.tif
# Saved Tileee_final/tile_1024_5120.tif
# Saved Tileee_final/tile_1024_5632.tif
# Saved Tileee_final/tile_1024_6144.tif
# Saved Tileee_final/tile_1024_6656.tif
# Saved Tileee_final/tile_1024_7168.tif
# Saved Tileee_final/tile_1024_7680.tif
# Saved Tileee_final/tile_1024_8192.tif
# Saved Tileee_final/tile_1024_8704.tif
# Saved Tileee_final/tile_1024_9216.tif
# Saved Tileee_final/tile_1024_9728.tif
# Saved Tileee_final/tile_1536_0.tif
# Saved Tileee_final/tile_1536_512.tif
# Saved Tileee_final/tile_1536_1024.tif
# Saved Tileee_final/tile_1536_1536.tif
# Saved Tileee_final/tile_1536_2048.tif
# Saved Tileee_final/tile_1536_2560.tif
# Saved Tileee_final/tile_1536_3072.tif
# Saved Tileee_final/tile_1536_3584.tif
# Saved Tileee_final/tile_1536_4096.tif
# Saved Tileee_final/tile_1536_4608.tif
# Saved Tileee_final/tile_1536_5120.tif
# Saved Tileee_final/tile_1536_5632.tif
# Saved Tileee_final/tile_1536_6144.tif
# Saved Tileee_final/tile_1536_6656.tif
# Saved Tileee_final/tile_1536_7168.tif
# Saved Tileee_final/tile_1536_7680.tif
# Saved Tileee_final/tile_1536_8192.tif
# Saved Tileee_final/tile_1536_8704.tif
# Saved Tileee_final/tile_1536_9216.tif
# Saved Tileee_final/tile_1536_9728.tif
# Saved Tileee_final/tile_2048_0.tif
# Saved Tileee_final/tile_2048_512.tif
# Saved Tileee_final/tile_2048_1024.tif
# Saved Tileee_final/tile_2048_1536.tif
# Saved Tileee_final/tile_2048_2048.tif
# Saved Tileee_final/tile_2048_2560.tif
# Saved Tileee_final/tile_2048_3072.tif
# Saved Tileee_final/tile_2048_3584.tif
# Saved Tileee_final/tile_2048_4096.tif
# Saved Tileee_final/tile_2048_4608.tif
# Saved Tileee_final/tile_2048_5120.tif
# Saved Tileee_final/tile_2048_5632.tif
# Saved Tileee_final/tile_2048_6144.tif
# Saved Tileee_final/tile_2048_6656.tif
# Saved Tileee_final/tile_2048_7168.tif
# Saved Tileee_final/tile_2048_7680.tif
# Saved Tileee_final/tile_2048_8192.tif
# Saved Tileee_final/tile_2048_8704.tif
# Saved Tileee_final/tile_2048_9216.tif
# Saved Tileee_final/tile_2048_9728.tif
# Saved Tileee_final/tile_2560_0.tif
# Saved Tileee_final/tile_2560_512.tif
# Saved Tileee_final/tile_2560_1024.tif
# Saved Tileee_final/tile_2560_1536.tif
# Saved Tileee_final/tile_2560_2048.tif
# Saved Tileee_final/tile_2560_2560.tif
# Saved Tileee_final/tile_2560_3072.tif
# Saved Tileee_final/tile_2560_3584.tif
# Saved Tileee_final/tile_2560_4096.tif
# Saved Tileee_final/tile_2560_4608.tif
# Saved Tileee_final/tile_2560_5120.tif
# Saved Tileee_final/tile_2560_5632.tif
# Saved Tileee_final/tile_2560_6144.tif
# Saved Tileee_final/tile_2560_6656.tif
# Saved Tileee_final/tile_2560_7168.tif
# Saved Tileee_final/tile_2560_7680.tif
# Saved Tileee_final/tile_2560_8192.tif
# Saved Tileee_final/tile_2560_8704.tif
# Saved Tileee_final/tile_2560_9216.tif
# Saved Tileee_final/tile_2560_9728.tif
# Saved Tileee_final/tile_3072_0.tif
# Saved Tileee_final/tile_3072_512.tif
# Saved Tileee_final/tile_3072_1024.tif
# Saved Tileee_final/tile_3072_1536.tif
# Saved Tileee_final/tile_3072_2048.tif
# Saved Tileee_final/tile_3072_2560.tif
# Saved Tileee_final/tile_3072_3072.tif
# Saved Tileee_final/tile_3072_3584.tif
# Saved Tileee_final/tile_3072_4096.tif
# Saved Tileee_final/tile_3072_4608.tif
# Saved Tileee_final/tile_3072_5120.tif
# Saved Tileee_final/tile_3072_5632.tif
# Saved Tileee_final/tile_3072_6144.tif
# Saved Tileee_final/tile_3072_6656.tif
# Saved Tileee_final/tile_3072_7168.tif
# Saved Tileee_final/tile_3072_7680.tif
# Saved Tileee_final/tile_3072_8192.tif
# Saved Tileee_final/tile_3072_8704.tif
# Saved Tileee_final/tile_3072_9216.tif
# Saved Tileee_final/tile_3072_9728.tif
# Saved Tileee_final/tile_3584_0.tif
# Saved Tileee_final/tile_3584_512.tif
# Saved Tileee_final/tile_3584_1024.tif
# Saved Tileee_final/tile_3584_1536.tif
# Saved Tileee_final/tile_3584_2048.tif
# Saved Tileee_final/tile_3584_2560.tif
# Saved Tileee_final/tile_3584_3072.tif
# Saved Tileee_final/tile_3584_3584.tif
# Saved Tileee_final/tile_3584_4096.tif
# Saved Tileee_final/tile_3584_4608.tif
# Saved Tileee_final/tile_3584_5120.tif
# Saved Tileee_final/tile_3584_5632.tif
# Saved Tileee_final/tile_3584_6144.tif
# Saved Tileee_final/tile_3584_6656.tif
# Saved Tileee_final/tile_3584_7168.tif
# Saved Tileee_final/tile_3584_7680.tif
# Saved Tileee_final/tile_3584_8192.tif
# Saved Tileee_final/tile_3584_8704.tif
# Saved Tileee_final/tile_3584_9216.tif
# Saved Tileee_final/tile_3584_9728.tif
# Saved Tileee_final/tile_4096_0.tif
# Saved Tileee_final/tile_4096_512.tif
# Saved Tileee_final/tile_4096_1024.tif
# Saved Tileee_final/tile_4096_1536.tif
# Saved Tileee_final/tile_4096_2048.tif
# Saved Tileee_final/tile_4096_2560.tif
# Saved Tileee_final/tile_4096_3072.tif
# Saved Tileee_final/tile_4096_3584.tif
# Saved Tileee_final/tile_4096_4096.tif
# Saved Tileee_final/tile_4096_4608.tif
# Saved Tileee_final/tile_4096_5120.tif
# Saved Tileee_final/tile_4096_5632.tif
# Saved Tileee_final/tile_4096_6144.tif
# Saved Tileee_final/tile_4096_6656.tif
# Saved Tileee_final/tile_4096_7168.tif
# Saved Tileee_final/tile_4096_7680.tif
# Saved Tileee_final/tile_4096_8192.tif
# Saved Tileee_final/tile_4096_8704.tif
# Saved Tileee_final/tile_4096_9216.tif
# Saved Tileee_final/tile_4096_9728.tif
# Saved Tileee_final/tile_4608_0.tif
# Saved Tileee_final/tile_4608_512.tif
# Saved Tileee_final/tile_4608_1024.tif
# Saved Tileee_final/tile_4608_1536.tif
# Saved Tileee_final/tile_4608_2048.tif
# Saved Tileee_final/tile_4608_2560.tif
# Saved Tileee_final/tile_4608_3072.tif
# Saved Tileee_final/tile_4608_3584.tif
# Saved Tileee_final/tile_4608_4096.tif
# Saved Tileee_final/tile_4608_4608.tif
# Saved Tileee_final/tile_4608_5120.tif
# Saved Tileee_final/tile_4608_5632.tif
# Saved Tileee_final/tile_4608_6144.tif
# Saved Tileee_final/tile_4608_6656.tif
# Saved Tileee_final/tile_4608_7168.tif
# Saved Tileee_final/tile_4608_7680.tif
# Saved Tileee_final/tile_4608_8192.tif
# Saved Tileee_final/tile_4608_8704.tif
# Saved Tileee_final/tile_4608_9216.tif
# Saved Tileee_final/tile_4608_9728.tif
# Saved Tileee_final/tile_5120_0.tif
# Saved Tileee_final/tile_5120_512.tif
# Saved Tileee_final/tile_5120_1024.tif
# Saved Tileee_final/tile_5120_1536.tif
# Saved Tileee_final/tile_5120_2048.tif
# Saved Tileee_final/tile_5120_2560.tif
# Saved Tileee_final/tile_5120_3072.tif
# Saved Tileee_final/tile_5120_3584.tif
# Saved Tileee_final/tile_5120_4096.tif
# Saved Tileee_final/tile_5120_4608.tif
# Saved Tileee_final/tile_5120_5120.tif
# Saved Tileee_final/tile_5120_5632.tif
# Saved Tileee_final/tile_5120_6144.tif
# Saved Tileee_final/tile_5120_6656.tif
# Saved Tileee_final/tile_5120_7168.tif
# Saved Tileee_final/tile_5120_7680.tif
# Saved Tileee_final/tile_5120_8192.tif
# Saved Tileee_final/tile_5120_8704.tif
# Saved Tileee_final/tile_5120_9216.tif
# Saved Tileee_final/tile_5120_9728.tif
# Saved Tileee_final/tile_5632_0.tif
# Saved Tileee_final/tile_5632_512.tif
# Saved Tileee_final/tile_5632_1024.tif
# Saved Tileee_final/tile_5632_1536.tif
# Saved Tileee_final/tile_5632_2048.tif
# Saved Tileee_final/tile_5632_2560.tif
# Saved Tileee_final/tile_5632_3072.tif
# Saved Tileee_final/tile_5632_3584.tif
# Saved Tileee_final/tile_5632_4096.tif
# Saved Tileee_final/tile_5632_4608.tif
# Saved Tileee_final/tile_5632_5120.tif
# Saved Tileee_final/tile_5632_5632.tif
# Saved Tileee_final/tile_5632_6144.tif
# Saved Tileee_final/tile_5632_6656.tif
# Saved Tileee_final/tile_5632_7168.tif
# Saved Tileee_final/tile_5632_7680.tif
# Saved Tileee_final/tile_5632_8192.tif
# Saved Tileee_final/tile_5632_8704.tif
# Saved Tileee_final/tile_5632_9216.tif
# Saved Tileee_final/tile_5632_9728.tif
# Saved Tileee_final/tile_6144_0.tif
# Saved Tileee_final/tile_6144_512.tif
# Saved Tileee_final/tile_6144_1024.tif
# Saved Tileee_final/tile_6144_1536.tif
# Saved Tileee_final/tile_6144_2048.tif
# Saved Tileee_final/tile_6144_2560.tif
# Saved Tileee_final/tile_6144_3072.tif
# Saved Tileee_final/tile_6144_3584.tif
# Saved Tileee_final/tile_6144_4096.tif
# Saved Tileee_final/tile_6144_4608.tif
# Saved Tileee_final/tile_6144_5120.tif
# Saved Tileee_final/tile_6144_5632.tif
# Saved Tileee_final/tile_6144_6144.tif
# Saved Tileee_final/tile_6144_6656.tif
# Saved Tileee_final/tile_6144_7168.tif
# Saved Tileee_final/tile_6144_7680.tif
# Saved Tileee_final/tile_6144_8192.tif
# Saved Tileee_final/tile_6144_8704.tif
# Saved Tileee_final/tile_6144_9216.tif
# Saved Tileee_final/tile_6144_9728.tif
# Saved Tileee_final/tile_6656_0.tif
# Saved Tileee_final/tile_6656_512.tif
# Saved Tileee_final/tile_6656_1024.tif
# Saved Tileee_final/tile_6656_1536.tif
# Saved Tileee_final/tile_6656_2048.tif
# Saved Tileee_final/tile_6656_2560.tif
# Saved Tileee_final/tile_6656_3072.tif
# Saved Tileee_final/tile_6656_3584.tif
# Saved Tileee_final/tile_6656_4096.tif
# Saved Tileee_final/tile_6656_4608.tif
# Saved Tileee_final/tile_6656_5120.tif
# Saved Tileee_final/tile_6656_5632.tif
# Saved Tileee_final/tile_6656_6144.tif
# Saved Tileee_final/tile_6656_6656.tif
# Saved Tileee_final/tile_6656_7168.tif
# Saved Tileee_final/tile_6656_7680.tif
# Saved Tileee_final/tile_6656_8192.tif
# Saved Tileee_final/tile_6656_8704.tif
# Saved Tileee_final/tile_6656_9216.tif
# Saved Tileee_final/tile_6656_9728.tif
# Saved Tileee_final/tile_7168_0.tif
# Saved Tileee_final/tile_7168_512.tif
# Saved Tileee_final/tile_7168_1024.tif
# Saved Tileee_final/tile_7168_1536.tif
# Saved Tileee_final/tile_7168_2048.tif
# Saved Tileee_final/tile_7168_2560.tif
# Saved Tileee_final/tile_7168_3072.tif
# Saved Tileee_final/tile_7168_3584.tif
# Saved Tileee_final/tile_7168_4096.tif
# Saved Tileee_final/tile_7168_4608.tif
# Saved Tileee_final/tile_7168_5120.tif
# Saved Tileee_final/tile_7168_5632.tif
# Saved Tileee_final/tile_7168_6144.tif
# Saved Tileee_final/tile_7168_6656.tif
# Saved Tileee_final/tile_7168_7168.tif
# Saved Tileee_final/tile_7168_7680.tif
# Saved Tileee_final/tile_7168_8192.tif
# Saved Tileee_final/tile_7168_8704.tif
# Saved Tileee_final/tile_7168_9216.tif
# Saved Tileee_final/tile_7168_9728.tif
# Saved Tileee_final/tile_7680_0.tif
# Saved Tileee_final/tile_7680_512.tif
# Saved Tileee_final/tile_7680_1024.tif
# Saved Tileee_final/tile_7680_1536.tif
# Saved Tileee_final/tile_7680_2048.tif
# Saved Tileee_final/tile_7680_2560.tif
# Saved Tileee_final/tile_7680_3072.tif
# Saved Tileee_final/tile_7680_3584.tif
# Saved Tileee_final/tile_7680_4096.tif
# Saved Tileee_final/tile_7680_4608.tif
# Saved Tileee_final/tile_7680_5120.tif
# Saved Tileee_final/tile_7680_5632.tif
# Saved Tileee_final/tile_7680_6144.tif
# Saved Tileee_final/tile_7680_6656.tif
# Saved Tileee_final/tile_7680_7168.tif
# Saved Tileee_final/tile_7680_7680.tif
# Saved Tileee_final/tile_7680_8192.tif
# Saved Tileee_final/tile_7680_8704.tif
# Saved Tileee_final/tile_7680_9216.tif
# Saved Tileee_final/tile_7680_9728.tif
# Saved Tileee_final/tile_8192_0.tif
# Saved Tileee_final/tile_8192_512.tif
# Saved Tileee_final/tile_8192_1024.tif
# Saved Tileee_final/tile_8192_1536.tif
# Saved Tileee_final/tile_8192_2048.tif
# Saved Tileee_final/tile_8192_2560.tif
# Saved Tileee_final/tile_8192_3072.tif
# Saved Tileee_final/tile_8192_3584.tif
# Saved Tileee_final/tile_8192_4096.tif
# Saved Tileee_final/tile_8192_4608.tif
# Saved Tileee_final/tile_8192_5120.tif
# Saved Tileee_final/tile_8192_5632.tif
# Saved Tileee_final/tile_8192_6144.tif
# Saved Tileee_final/tile_8192_6656.tif
# Saved Tileee_final/tile_8192_7168.tif
# Saved Tileee_final/tile_8192_7680.tif
# Saved Tileee_final/tile_8192_8192.tif
# Saved Tileee_final/tile_8192_8704.tif
# Saved Tileee_final/tile_8192_9216.tif
# Saved Tileee_final/tile_8192_9728.tif
# Saved Tileee_final/tile_8704_0.tif
# Saved Tileee_final/tile_8704_512.tif
# Saved Tileee_final/tile_8704_1024.tif
# Saved Tileee_final/tile_8704_1536.tif
# Saved Tileee_final/tile_8704_2048.tif
# Saved Tileee_final/tile_8704_2560.tif
# Saved Tileee_final/tile_8704_3072.tif
# Saved Tileee_final/tile_8704_3584.tif
# Saved Tileee_final/tile_8704_4096.tif
# Saved Tileee_final/tile_8704_4608.tif
# Saved Tileee_final/tile_8704_5120.tif
# Saved Tileee_final/tile_8704_5632.tif
# Saved Tileee_final/tile_8704_6144.tif
# Saved Tileee_final/tile_8704_6656.tif
# Saved Tileee_final/tile_8704_7168.tif
# Saved Tileee_final/tile_8704_7680.tif
# Saved Tileee_final/tile_8704_8192.tif
# Saved Tileee_final/tile_8704_8704.tif
# Saved Tileee_final/tile_8704_9216.tif
# Saved Tileee_final/tile_8704_9728.tif
# Saved Tileee_final/tile_9216_0.tif
# Saved Tileee_final/tile_9216_512.tif
# Saved Tileee_final/tile_9216_1024.tif
# Saved Tileee_final/tile_9216_1536.tif
# Saved Tileee_final/tile_9216_2048.tif
# Saved Tileee_final/tile_9216_2560.tif
# Saved Tileee_final/tile_9216_3072.tif
# Saved Tileee_final/tile_9216_3584.tif
# Saved Tileee_final/tile_9216_4096.tif
# Saved Tileee_final/tile_9216_4608.tif
# Saved Tileee_final/tile_9216_5120.tif
# Saved Tileee_final/tile_9216_5632.tif
# Saved Tileee_final/tile_9216_6144.tif
# Saved Tileee_final/tile_9216_6656.tif
# Saved Tileee_final/tile_9216_7168.tif
# Saved Tileee_final/tile_9216_7680.tif
# Saved Tileee_final/tile_9216_8192.tif
# Saved Tileee_final/tile_9216_8704.tif
# Saved Tileee_final/tile_9216_9216.tif
# Saved Tileee_final/tile_9216_9728.tif
# Saved Tileee_final/tile_9728_0.tif
# Saved Tileee_final/tile_9728_512.tif
# Saved Tileee_final/tile_9728_1024.tif
# Saved Tileee_final/tile_9728_1536.tif
# Saved Tileee_final/tile_9728_2048.tif
# Saved Tileee_final/tile_9728_2560.tif
# Saved Tileee_final/tile_9728_3072.tif
# Saved Tileee_final/tile_9728_3584.tif
# Saved Tileee_final/tile_9728_4096.tif
# Saved Tileee_final/tile_9728_4608.tif
# Saved Tileee_final/tile_9728_5120.tif
# Saved Tileee_final/tile_9728_5632.tif
# Saved Tileee_final/tile_9728_6144.tif
# Saved Tileee_final/tile_9728_6656.tif
# Saved Tileee_final/tile_9728_7168.tif
# Saved Tileee_final/tile_9728_7680.tif
# Saved Tileee_final/tile_9728_8192.tif
# Saved Tileee_final/tile_9728_8704.tif
# Saved Tileee_final/tile_9728_9216.tif
# Saved Tileee_final/tile_9728_9728.tif
# Tiling complete!
# All tiles have been saved and zipped into Tileee_final/tiles.zip
